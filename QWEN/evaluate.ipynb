# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix

csv_file = r"D:\Documents\MASC\NLP_EMO\emotion_results_sp_002_002 (7).csv"  # Replace with your CSV file path
data = pd.read_csv(csv_file)

# Extract "Label" and "Mapped Value" columns
true_labels = data["Label"].astype(int)
predicted_labels = data["Mapped Value"].astype(int)

# Calculate metrics
accuracy = accuracy_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels, average='weighted')  # Use 'macro' for unweighted F1
uar = recall_score(true_labels, predicted_labels, average='macro')  # Macro-average Recall is UAR

# Print the metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"UAR (Unweighted Average Recall): {uar:.4f}")
print(f"F1-Score: {f1:.4f}")

# Create confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1, 2, 3], yticklabels=[0, 1, 2, 3])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 0.7461
# UAR (Unweighted Average Recall): 0.6479
# F1-Score: 0.7245

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix

csv_file = r"D:\Documents\MASC\NLP_EMO\emotion_results_sp_002_nofew.csv"  # Replace with your CSV file path
data = pd.read_csv(csv_file)

# Extract "Label" and "Mapped Value" columns
true_labels = data["Label"].astype(int)
predicted_labels = data["Mapped Value"].astype(int)

# Calculate metrics
accuracy = accuracy_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels, average='weighted')  # Use 'macro' for unweighted F1
uar = recall_score(true_labels, predicted_labels, average='macro')  # Macro-average Recall is UAR

# Print the metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"UAR (Unweighted Average Recall): {uar:.4f}")
print(f"F1-Score: {f1:.4f}")

# Create confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1, 2, 3], yticklabels=[0, 1, 2, 3])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 0.7461
# UAR (Unweighted Average Recall): 0.6447
# F1-Score: 0.7231

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix

csv_file = r"D:\Documents\MASC\NLP_EMO\sp_002_16shot_3.csv"  # Replace with your CSV file path
data = pd.read_csv(csv_file)

# Extract "Label" and "Mapped Value" columns
true_labels = data["Label"].astype(int)
predicted_labels = data["Mapped Value"].astype(int)

# Calculate metrics
accuracy = accuracy_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels, average='weighted')  # Use 'macro' for unweighted F1
uar = recall_score(true_labels, predicted_labels, average='macro')  # Macro-average Recall is UAR

# Print the metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"UAR (Unweighted Average Recall): {uar:.4f}")
print(f"F1-Score: {f1:.4f}")

# Create confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1, 2, 3], yticklabels=[0, 1, 2, 3])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 0.7595
# UAR (Unweighted Average Recall): 0.6666
# F1-Score: 0.7414

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix

csv_file = r"D:\Documents\MASC\NLP_EMO\sp_002_16_NoShot.csv"  # Replace with your CSV file path
data = pd.read_csv(csv_file)

# Extract "Label" and "Mapped Value" columns
true_labels = data["Label"].astype(int)
predicted_labels = data["Mapped Value"].astype(int)

# Calculate metrics
accuracy = accuracy_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels, average='weighted')  # Use 'macro' for unweighted F1
uar = recall_score(true_labels, predicted_labels, average='macro')  # Macro-average Recall is UAR

# Print the metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"UAR (Unweighted Average Recall): {uar:.4f}")
print(f"F1-Score: {f1:.4f}")

# Create confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1, 2, 3], yticklabels=[0, 1, 2, 3])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 0.7595
# UAR (Unweighted Average Recall): 0.6673
# F1-Score: 0.7410

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix

csv_file = r"D:\Documents\MASC\NLP_EMO\EmoSpeech\QWEN\emotion_results_937_trainsplit_e40.csv"  # Replace with your CSV file path
data = pd.read_csv(csv_file)

# Extract "Label" and "Mapped Value" columns
true_labels = data["Label"].astype(int)
predicted_labels = data["Mapped Value"].astype(int)

# Calculate metrics
accuracy = accuracy_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels, average='weighted')  # Use 'macro' for unweighted F1
uar = recall_score(true_labels, predicted_labels, average='macro')  # Macro-average Recall is UAR

# Print the metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"UAR (Unweighted Average Recall): {uar:.4f}")
print(f"F1-Score: {f1:.4f}")

# Create confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1, 2, 3], yticklabels=[0, 1, 2, 3])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 0.7239
# UAR (Unweighted Average Recall): 0.5918
# F1-Score: 0.6937

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix

csv_file = r"H:\My Drive\MASC\QWEN2\all_speakers.csv"  # Replace with your CSV file path
data_all = pd.read_csv(csv_file)

# Extract "Label" and "Mapped Value" columns
true_labels = data_all["Label"].astype(int)
predicted_labels = data_all["Mapped Value"].astype(int)

# Calculate metrics
accuracy = accuracy_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels, average='weighted')  # Use 'macro' for unweighted F1
uar = recall_score(true_labels, predicted_labels, average='macro')  # Macro-average Recall is UAR

# Print the metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"UAR (Unweighted Average Recall): {uar:.4f}")
print(f"F1-Score: {f1:.4f}")

# Create confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1, 2, 3], yticklabels=[0, 1, 2, 3])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 0.6817
# UAR (Unweighted Average Recall): 0.5988
# F1-Score: 0.6630

# %%
data_all_2 = data_all[data_all['speakerIDs'] == 1]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix

# Extract "Label" and "Mapped Value" columns
true_labels = data_all_2["Label"].astype(int)
predicted_labels = data_all_2["Mapped Value"].astype(int)

# Calculate metrics
accuracy = accuracy_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels, average='weighted')  # Use 'macro' for unweighted F1
uar = recall_score(true_labels, predicted_labels, average='macro')  # Macro-average Recall is UAR

# Print the metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"UAR (Unweighted Average Recall): {uar:.4f}")
print(f"F1-Score: {f1:.4f}")

# Create confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1, 2, 3], yticklabels=[0, 1, 2, 3])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 0.6625
# UAR (Unweighted Average Recall): 0.5591
# F1-Score: 0.6184
